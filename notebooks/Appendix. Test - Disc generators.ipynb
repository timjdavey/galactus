# %%
import nbsetup
import numpy as np
import seaborn as sns
from models.space import Space
from models import disc

# %% [markdown]
# # Disc mass generators

# %%
# 1/r falloff from 1 in the centre
fallout = disc.generate(50, disc.falloff)
sns.heatmap(fallout)
# Out:
# <AxesSubplot:>

# %%
# flat 1 disc of r = 10 on space 50
disk = disc.generate(50, disc.disc(10))
sns.heatmap(disk)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plotted in Space

# %%
space = Space([disk])
space.quiver()
space.line()
