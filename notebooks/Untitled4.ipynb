# %%
import nbsetup
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from models.load import load

# %%
less = load('milky_scale_11')
less.rotate('x','z')
less.mass_profile()

# %%
more = load('milky_scale_21')
more.rotate('x','z')
more.mass_profile()
