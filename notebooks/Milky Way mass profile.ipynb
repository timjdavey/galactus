# %%
import nbsetup
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from models.milky import MilkyWay

# %%
milk = MilkyWay(500, 30, cp=nbsetup.cp, lazy=True)

# %%
mass_profile(milk)

# %%
#milk.reset_rotation()
milk.rotate('y','z')

# %%
mass_profile(milk)
