# %%
import nbsetup
from models.milky import MilkyWay, buldge, thick, thin

# %%
total_points = 100
total_radius = 15
for p in [buldge, thick, thin]:
    sim = MilkyWay(points=total_points, radius=total_radius, cp=nbsetup.cp, profiles=[p])
    sim.rotate('y','z')
    sim.mass_profile()

# %%
al = MilkyWay(points=total_points, radius=total_radius, cp=nbsetup.cp)
al.rotate('y','z')
al.mass_profile()
