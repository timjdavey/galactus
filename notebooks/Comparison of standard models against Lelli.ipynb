# %%
import nbsetup
from models.load import load_sparc
from models.sparc.result import Result

# %%
standard = Result(load_sparc(namespace='sparc_standard'))
standard.plot_rar(idens=('V', 'S'), query_key=None)
# Out:
# <AxesSubplot:xlabel='Log of Baryonic g', ylabel='Log of Observed g'>

# %%
standard.plot_thresholds()

# %%
standard.statistics()
# Out:
#              dataset observation        r2          RMSE          MAE  \
# 0         Everything    little g  0.601857  13129.353698  2905.687206
# 1         Everything    velocity  0.520476     60.375824    48.814456
# 2          Threshold    little g  0.741185   5829.713193  1656.462993
# 3          Threshold    velocity  0.304168     68.496431    58.778526
# 4            Quality    little g  0.602073  14167.527697  3082.183865
# 5            Quality    velocity  0.532393     59.888824    48.300323
# 6  Quality_Threshold    little g  0.742537   6350.210877  1733.195203
# 7  Quality_Threshold    velocity  0.296945     68.813627    59.085655
# 8     Anti_Threshold    little g  0.532551  21698.544842  5599.634303
# 9     Anti_Threshold    velocity  0.847455     37.261533    27.326976
#
#        MLSE  Res(Log y)  Res(Log mhi_R)
# 0  1.548841   -0.354810        0.380005
# 1  0.372077   -0.354810        0.380005
# 2  1.840933   -0.371704        0.349203
# 3  0.445198   -0.371704        0.349203
# 4  1.566589   -0.348500        0.387425
# 5  0.376110   -0.348500        0.387425
# 6  1.912178   -0.367867        0.361110
# 7  0.462137   -0.367867        0.361110
# 8  0.918944   -0.293891        0.304373
# 9  0.214393   -0.293891        0.304373
