# %%
import nbsetup
import numpy as np
import seaborn as sns
import scipy as sp
import pandas as pd

# %%
from models.load import load_sparc
from models.sparc.result import Result
from models.sparc.mcmc import mcmc
from models.sparc.analysis import Analysis
from models.equations import velocity

# %%
standard = Result(load_sparc(namespace='sparc_standard'))
standard.plot_rar()
# Out:
# <AxesSubplot:title={'center':'Everything'}, xlabel='Log of Baryonic g', ylabel='Log of Observed g'>

# %%
simulations = load_sparc()
inputs = Result(simulations)
inputs.plot_rar()
# Out:
# <AxesSubplot:title={'center':'Everything'}, xlabel='Log of Baryonic g', ylabel='Log of Observed g'>

# %%
aa = Analysis(mcmc(inputs.dataframe, tight={'Inc': 1.6, 'D': 3, 'Ymass': 15}), name='Experiment')
outputs = aa.Result(simulations=simulations, fast=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3193' class='' max='3193' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3193/3193 00:05<00:00 logp = -44,151, ||grad|| = 9.7919]
#     </div>

# %%
g, data = outputs.residual_hist()
data.mean(), data.std()
# Out:
# (0.01753687886766898, 0.10995078941599755)

# %%
outputs.plot_rar()
# Out:
# <AxesSubplot:title={'center':'Everything'}, xlabel='Log of Baryonic g', ylabel='Log of Observed g'>

# %%
g = outputs.residual()
g.set(xlim=(2.5,4.5), xlabel="Log of Predicted g", ylabel="Residuals")
# Out:
# [(2.5, 4.5), Text(0.5, 0, 'Log of Predicted g'), Text(0, 0.5, 'Residuals')]

# %%
outputs.residual(plot=False).slope
# Out:
# -0.03305282682894563

# %%
aa.plot_nuissance()
# Out:
# <AxesSubplot:xlabel='Galaxy in order of SPARC reference parameter value', ylabel='Mass/Luminosity adjustment'>
